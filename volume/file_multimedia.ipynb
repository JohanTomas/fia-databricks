# %%
# COMMAND ----------
# PUNTO 4: Lectura y vinculación de archivos en Volumen (Unity Catalog)

# Reemplaza 'main' y 'default' por el nombre exacto de tu Catálogo y Esquema
ruta_volumen = "/Volumes/workspace/default/archivos_multimedia/"

print("Verificando archivos subidos en el Volumen...")

# Listar contenido del volumen
archivos = dbutils.fs.ls(ruta_volumen)

for archivo in archivos:
    print(f"📁 Archivo detectado: {archivo.name} | Tamaño: {archivo.size} bytes | Ruta: {archivo.path}")
